# %%
import pandas as pd
import numpy as np

# Basic models and tools
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

# XGBoost and LightGBM
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

# VotingClassifier
from sklearn.ensemble import VotingClassifier

# ========== 1. Load data ==========

df = pd.read_csv('food_partial_labeled.csv')
# Columns: "food"(string), "category"(string), remaining columns are numeric features

# ========== 2. Split labeled/unlabeled data ==========

df_labeled = df.dropna(subset=["category"]).copy()   # labeled data
df_unlabeled = df[df["category"].isna()].copy()      # unlabeled data

# ========== 3. Define feature columns ==========

num_cols = df.columns.difference(["food", "category"])
features = list(num_cols)

# ========== 4. Prepare X and y ==========

X_labeled = df_labeled[features].copy()
y_labeled = df_labeled["category"].copy()

# Fill missing values (using mean)
X_labeled = X_labeled.fillna(X_labeled.mean())

# Encode labels ("meats", "vegetables", "carbs")
le = LabelEncoder()
y_labeled_encoded = le.fit_transform(y_labeled)

# ========== 5. Train-validation split and scaling ==========

X_train, X_val, y_train, y_val = train_test_split(
    X_labeled, y_labeled_encoded, 
    test_size=0.2, random_state=42, 
    stratify=y_labeled_encoded
)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.transform(X_val)

# ========== 6. Define four base models ==========

clf_lr = LogisticRegression(random_state=42)
clf_svc = SVC(probability=True, random_state=42)
clf_xgb = XGBClassifier(use_label_encoder=False, eval_metric="logloss", random_state=42)
clf_lgb = LGBMClassifier(random_state=42)

# ========== 7. Build VotingClassifier (soft voting) ==========

voting_clf = VotingClassifier(
    estimators=[
        ("lr", clf_lr),
        ("svc", clf_svc),
        ("xgb", clf_xgb),
        ("lgb", clf_lgb)
    ],
    voting="soft"
)

voting_clf.fit(X_train_scaled, y_train)

# Evaluate on validation set
val_accuracy = voting_clf.score(X_val_scaled, y_val)
print("Validation Accuracy:", val_accuracy)

# ========== 8. Predict unlabeled data and mark uncertain predictions as "others" ==========

X_unlabeled = df_unlabeled[features].copy()
X_unlabeled = X_unlabeled.fillna(X_unlabeled.mean())
X_unlabeled_scaled = scaler.transform(X_unlabeled)

proba_unlabeled = voting_clf.predict_proba(X_unlabeled_scaled)

threshold = 0.9  # Adjust threshold if necessary
pred_labels = []
for row_prob in proba_unlabeled:
    max_prob = np.max(row_prob)
    class_idx = np.argmax(row_prob)
    if max_prob < threshold:
        pred_labels.append("others")
    else:
        pred_labels.append(le.inverse_transform([class_idx])[0])

df_unlabeled["category_pred"] = pred_labels

# ========== 9. Post-processing: Change "meats" predictions containing dairy keywords to "others" ==========

dairy_keywords = ["cheese", "cream", "milk"]

for i in df_unlabeled.index:
    predicted_cat = df_unlabeled.at[i, "category_pred"]
    food_name = str(df_unlabeled.at[i, "food"]).lower()

    if predicted_cat == "meats" and any(kw in food_name for kw in dairy_keywords):
        df_unlabeled.at[i, "category_pred"] = "others"

# ========== 10. Display statistics ==========

print("Unlabeled data prediction distribution:")
print(df_unlabeled["category_pred"].value_counts())

print("\nDetailed statistics by category:")
for cat_name, count in df_unlabeled["category_pred"].value_counts().items():
    print(f"{cat_name}: {count} samples")

# Print foods predicted as vegetables
print("\nFoods predicted as vegetables:")
vegetables_records = df_unlabeled[df_unlabeled["category_pred"] == "vegetables"]
if not vegetables_records.empty:
    print(f"Total {len(vegetables_records)} samples:")
    for food in vegetables_records["food"]:
        print(f"- {food}")
else:
    print("No samples predicted as vegetables")

# Print foods predicted as meats
print("\nFoods predicted as meats:")
meats_records = df_unlabeled[df_unlabeled["category_pred"] == "meats"]
if not meats_records.empty:
    print(f"Total {len(meats_records)} samples:")
    for food in meats_records["food"]:
        print(f"- {food}")
else:
    print("No samples predicted as meats")

# Print foods predicted as carbs
print("\nFoods predicted as carbs:")
carbs_records = df_unlabeled[df_unlabeled["category_pred"] == "carbs"]
if not carbs_records.empty:
    print(f"Total {len(carbs_records)} samples:")
    for food in carbs_records["food"]:
        print(f"- {food}")
else:
    print("No samples predicted as carbs")

# ========== (Optional) Save results ==========

df_unlabeled.to_csv("food_labeled.csv", index=False)
# Out:
# /Users/kaiyuyang/miniconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [19:58:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000457 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 506
# [LightGBM] [Info] Number of data points in the train set: 48, number of used features: 34
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Validation Accuracy: 1.0
# Unlabeled data prediction distribution:
# category_pred
# others        1793
# meats          258
# carbs          164
# vegetables     120
# Name: count, dtype: int64
#
# 每个类别的详细统计：
# others: 1793 个样本
# meats: 258 个样本
# carbs: 164 个样本
# vegetables: 120 个样本
#
# 所有预测为vegetables类别的食物：
# 共找到 120 个vegetables样本：
# - broccoli raab raw
# - napa cabbage cooked
# - kelp
# - shallots raw
# - red lettuce
# - romanesco raw
# - lemongrass citronella
# - celery cooked
# - serrano pepper
# - sweet potato leaves cooked
# - collard raw
# - tomatillos
# - taro shoots raw
# - leeks dried
# - sweet red peppers cooked
# - purslane raw
# - sweet potato leaves raw
# - chicory greens
# - radish seeds sprouted
# - jute raw
# - hot chile pepper dried
# - crookneck squash raw
# - indian squash cooked
# - cauliflower cooked
# - laver seaweed
# - pumpkin flowers raw
# - mustard greens raw
# - arrowhead
# - pumpkin leaves cooked
# - hungarian pepper
# - chinese cabbage pe tsai raw
# - pumpkin flowers cooked
# - endive
# - agar
# - watercress
# - new zealand spinach raw
# - baby zucchini
# - amaranth leaves
# - turnip greens raw
# - spaghetti squash raw
# - cucumber
# - bamboo shoots cooked
# - summer squash raw
# - green tomato
# - beet greens raw
# - savoy cabbage cooked
# - witloof chicory
# - turnips cooked
# - dried tomatoes
# - radicchio
# - yellow tomato
# - kale raw
# - red chili peppers
# - brussels sprouts cooked
# - carrots cooked
# - lambs quarters raw
# - lotus root cooked
# - radish raw
# - baby carrots
# - taro leaves raw
# - drumstick leaves raw
# - scallop squash raw
# - gourd raw
# - romaine lettuce
# - prairie turnips raw
# - savoy cabbage raw
# - white icicle radish
# - orange tomato
# - pumpkin leaves raw
# - string beans wellsley farms
# - beets cooked
# - shallots dried
# - prairie turnips boiled
# - summer squash cooked
# - spring onion scallions
# - jalapeno pepper
# - sesbania flower raw
# - spirulina dried
# - zucchini cooked
# - green olives pickled
# - grape leaves
# - skunk cabbage
# - banana pepper
# - oriental radish raw
# - rhubarb raw
# - mung bean sprouts raw
# - onion cooked
# - swiss chard raw
# - cabbage cooked
# - asparagus raw
# - chinese cabbage pak choi raw
# - sweet green peppers cooked
# - dried tomatoes canned in oil
# - straw mushrooms canned
# - tomatoes in tomato juice canned
# - asparagus canned
# - onions canned
# - turnip greens canned
# - hearts of palm
# - crookneck squash canned
# - pimento canned
# - peas canned
# - beets canned
# - vegetable salad
# - iceberg lettuce
# - cornsalad
# - side salad mcdonalds
# - celtuce
# - arugula
# - shiitake mushrooms cooked
# - shiitake mushrooms raw
# - crimini mushrooms
# - maitake mushrooms
# - shiitake mushrooms dried
# - chanterelle mushrooms
# - jews ear
# - enoki mushrooms
# - morel mushrooms
# - portabella mushrooms raw
# - oyster mushroom
#
# 所有预测为meats类别的食物：
# 共找到 258 个meats样本：
# - scrambled eggs
# - omelet
# - poached egg
# - egg mix
# - crispy chicken drumstick kentucky fried chicken
# - chicken crispy drumsticks kentucky fried chicken
# - crispy chicken breast kentucky fried chicken
# - crispy chicken thigh kentucky fried chicken
# - scrambled eggs mcdonalds
# - beef sandwich steak raw
# - sucker raw
# - haddock cooked
# - burbot cooked
# - rainbow smelt raw
# - whitefish cooked
# - carp cooked
# - wolffish cooked
# - snapper cooked
# - roe cooked
# - herring raw
# - cod raw
# - tilapia raw
# - whiting cooked
# - skipjack tuna cooked
# - chum salmon cooked
# - american shad cooked
# - shark cooked
# - trout cooked
# - swordfish raw
# - mullet raw
# - lingcod raw
# - cisco raw
# - florida pompano cooked
# - snapper raw
# - cod cooked
# - seatrout raw
# - flounder raw
# - spot cooked
# - mackerel cooked
# - tilapia cooked
# - drum raw
# - wolffish raw
# - bluefin tuna cooked
# - herring cooked
# - bluefish raw
# - sheepshead cooked
# - pout cooked
# - rockfish raw
# - tilefish raw
# - scup raw
# - sablefish cooked
# - coho salmon cooked
# - sea bass raw
# - whitefish raw
# - greenland halibut cooked
# - chinook salmon cooked
# - mullet cooked
# - butterfish raw
# - sea bass cooked
# - greenland halibut raw
# - sturgeon cooked
# - rainbow trout raw
# - pout raw
# - rainbow smelt cooked
# - trout raw
# - shark raw
# - burbot raw
# - dolphinfish cooked
# - dolphinfish raw
# - cusk raw
# - carp raw
# - sturgeon raw
# - flounder cooked
# - catfish raw
# - coho salmon raw
# - yellowfin tuna cooked
# - ling cooked
# - eel cooked
# - sablefish raw
# - yellowtail raw
# - caviar
# - catfish cooked
# - whiting raw
# - pink salmon raw
# - mackerel raw
# - turbot raw
# - atlantic croaker raw
# - spot raw
# - tilefish cooked
# - bluefish cooked
# - grouper cooked
# - sheepshead raw
# - herring kippered
# - ocean perch cooked
# - ling raw
# - lingcod cooked
# - florida pompano raw
# - rockfish cooked
# - seatrout cooked
# - american shad raw
# - tuna canned
# - squid fried
# - haddock smoked
# - red salmon sockeye filets smoked
# - egg yolk dried
# - egg raw
# - egg yolk raw
# - egg dried
# - egg boiled
# - lamb foreshank raw
# - lamb rib cooked
# - lamb shank raw
# - ground lamb cooked
# - lamb meat cooked
# - lamb leg raw
# - lamb shank roasted
# - lamb sirloin cooked
# - lamb loin raw
# - lamb sirloin raw
# - sausage patty mcdonalds
# - lamb foreshank cooked
# - lamb shoulder raw
# - lamb meat raw
# - lamb shoulder cooked
# - veal rib cooked
# - veal meat cooked
# - veal sirloin raw
# - beef top loin filet grilled
# - mock tender steak raw
# - veal rib raw
# - ground veal raw
# - veal leg round raw
# - beef plate steak grilled
# - ground veal cooked
# - veal leg round cooked
# - porterhouse steak raw
# - veal shank raw
# - veal breast cooked
# - rib eye steak grilled
# - t bone steak raw
# - mock tender steak cooked
# - beef round steak cooked
# - chuck blade roast raw
# - beef shoulder steak raw
# - beef top blade cooked
# - corned beef cooked
# - beef round steak raw
# - beef shoulder steak grilled
# - chuck eye steak raw
# - beef bottom round steak cooked
# - porterhouse steak cooked
# - beef plate steak raw
# - beef meat canned
# - beef breakfast strips raw
# - rib eye steak raw
# - beef tenderloin steak cooked
# - chuck blade roast cooked
# - beef flank steak cooked
# - veal meat raw
# - veal loin cooked
# - veal loin raw
# - veal shoulder cooked
# - beef tenderloin steak raw
# - veal shank cooked
# - beef brisket raw
# - pastrami beef
# - beef flank steak raw
# - beef top sirloin steak cooked
# - veal breast raw
# - beef pork bologna
# - pork breakfast strips raw
# - pork bologna
# - lebanon bologna
# - turkey roll
# - luncheon meat pork beef
# - beef bologna
# - ostrich leg raw
# - ostrich strip raw
# - ostrich tenderloin raw
# - ground bison cooked
# - goat meat raw
# - ground emu raw
# - ground ostrich raw
# - ostrich tip cooked
# - caribou cooked
# - ground ostrich cooked
# - ostrich leg cooked
# - ostrich top loin cooked
# - ostrich strip cooked
# - ground bison raw
# - ostrich fan raw
# - ostrich top loin raw
# - veal tongue cooked
# - veal thymus cooked
# - beef pancreas cooked
# - chicken gizzard cooked
# - pork pancreas cooked
# - beef tongue cooked
# - lamb heart cooked
# - chicken heart cooked
# - lamb tongue cooked
# - veal heart cooked
# - lamb pancreas cooked
# - turkey gizzard cooked
# - turkey heart cooked
# - lamb lungs cooked
# - pork kidneys cooked
# - pork heart cooked
# - beef lungs cooked
# - veal lungs cooked
# - pork meat cooked
# - pork blade roll raw
# - pork stomach cooked
# - pork country style ribs raw
# - ham patties
# - pork leg cap steak cooked
# - pork blade chops raw
# - pork leg cap steak raw
# - pork centre loin chops raw
# - pork blade chops cooked
# - boston butt steak cooked
# - pork meat raw
# - pork top loin chops raw
# - pork boston steaks cooked
# - pickled pork hocks
# - pork boston roast cooked
# - ham steak
# - salt pork raw
# - ground pork raw
# - pork tail cooked
# - pork centre rib roasts raw
# - minced ham
# - ham roasted
# - pork loin raw
# - ham raw
# - ham extra lean
# - pork country style ribs cooked
# - pork blade steak raw
# - pork loin cooked
# - pork tongue cooked
# - ham patties grilled
# - chicken skin roasted
# - turkey breast raw
# - turkey roast roasted
# - chicken back raw
# - chicken back cooked
# - chicken leg raw
# - chicken neck cooked
# - duck meat cooked
# - chicken wing roasted
# - goose meat cooked
# - duck egg
# - pheasant breast raw
# - squab meat raw
# - chicken drumstick raw
# - turkey meat roasted
# - chicken breast raw
# - turkey wing cooked
#
# 所有预测为carbs类别的食物：
# 共找到 164 个carbs样本：
# - corn tamale
# - hummus
# - arroz con grandules
# - arroz con abichuelas
# - succotash
# - fried rice
# - arroz con frijoles
# - burrito with beans cheese
# - spinach spaghetti cooked
# - corn pasta cooked
# - cheese tortellini
# - bean ham soup
# - split pea soup with ham bacon
# - pea soup
# - bean with bacon soup
# - cream of rice coup
# - split pea soup
# - potato wedges kentucky fried chicken
# - nachos taco bell
# - cheese ravioli canned
# - tapioca pearls
# - millet flour
# - corn flour white
# - rice flour brown
# - sorghum flour
# - cornmeal whole grain
# - cornmeal white
# - barley flour
# - whole grain wheat flour
# - corn flour yellow
# - corn flour whole grain
# - acorn flour
# - rice flour white
# - cornmeal yellow
# - rye flour
# - arrowroot flour
# - chickpea flour
# - wheat flour
# - cornstarch
# - buckwheat flour
# - apple pie
# - chocolate cream pie
# - blueberry pie
# - yellow cake with vanilla frosting
# - pineapple cake
# - fruit coffeecake
# - coffeecake with chocolate frosting
# - yellow cake
# - cherry pie
# - chocolate cake
# - halavah
# - crispy brown rice
# - amaranth cooked
# - bulgur dry
# - teff cooked
# - couscous dry
# - oat bran cooked
# - buckwheat cooked
# - kamut cooked
# - spelt cooked
# - popcorn unpopped
# - whole wheat cooked
# - wheat sprouted
# - whole wheat dry
# - sorghum
# - barley cooked
# - quinoa dry
# - wheat shredded
# - rice pilaf cooked
# - wild rice cooked
# - wild rice raw
# - white rice pasta cooked
# - instant white rice raw
# - instant white rice cooked
# - rice cracker cake
# - parboiled white rice cooked
# - white rice steamed
# - glutinous white rice raw
# - glutinous white rice cooked
# - beef flavored rice cooked
# - chicken flavored rice cooked
# - prunes stewed
# - prunes
# - wild raspberries
# - japanese persimmon dried
# - elderberries
# - orange with peel
# - rambutan canned
# - prunes canned
# - sour cherries canned
# - mangosteen canned
# - fruit salad canned
# - gooseberries canned
# - raisins seeded
# - prune plums dried
# - sapodilla
# - wasabi root
# - chickpeas canned
# - white beans canned
# - black eyed cowpeas raw
# - cowpeas canned
# - winged beans cooked
# - lima beans canned
# - snap beans canned
# - navy beans canned
# - cranberry beans canned
# - black beans cooked
# - fava beans canned
# - pigeon peas cooked
# - navy beans cooked
# - mothbeans cooked
# - shellie beans canned
# - pinto beans canned
# - chickpeas cooked
# - mungo beans cooked
# - lemon pudding
# - instant coffee powder
# - cranberry apricot juice
# - cranberry grape juice
# - fruit punch
# - grape soda
# - clam tomato juice
# - lupins cooked
# - ginkgo nuts canned
# - lotus seeds dried
# - chia seeds dried
# - chestnuts raw
# - pectin
# - corn grits cooked
# - amaranth flakes
# - vegetable macaroni dry
# - chow mein noodles
# - chinese noodles
# - vegetable macaroni cooked
# - corn pasta dry
# - japanese somen noodles cooked
# - whole wheat macaroni dry
# - macaroni raw
# - japanese somen noodles dry
# - pasta cooked
# - rice noodles cooked
# - whole wheat macaroni cooked
# - whole wheat spaghetti cooked
# - bread crumbs
# - tortilla
# - sweet cheese rolls
# - cinnamon toaster pastry
# - arepa
# - frybread
# - pita bread
# - english muffin
# - rye dinner roll
# - english muffin whole wheat
# - oat bran bagel
# - english muffin toasted
# - english muffin whole wheat toasted
# - tropical trail mix
# - soft pretzels
# - cracker meal
# - melba toast crackers
# - russet potato raw
# - potato puffs
# - tomato sauce with herbs cheese
# - soybean dry roasted
# /Users/kaiyuyang/miniconda3/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Users/kaiyuyang/miniconda3/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
